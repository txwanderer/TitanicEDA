# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dframe = pd.read_csv("train.csv")

# %% [markdown]
# **PassegnerID EDA**
#
# Is PassengerID categorical or continuous?

# %%
dframe.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# dtype: int64

# %% [markdown]
# PassengerID is continuous.  A unique Passenger ID assigned to a passenger.

# %% [markdown]
# Are there null values for PassengerID?

# %%
dframe[dframe.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There are no null values for PassengerID

# %% [markdown]
# Minimum value for Passenger ID

# %%
dframe.PassengerId.min()
# Out:
# 1

# %% [markdown]
# Maximum value for PassengerID

# %%
dframe.PassengerId.max()
# Out:
# 891

# %% [markdown]
# Mean for PassengerID

# %%
dframe.PassengerId.mean()
# Out:
# 446.0

# %% [markdown]
# Standard Deviation for PassengerID

# %%
dframe.PassengerId.std()
# Out:
# 257.3538420152301

# %% [markdown]
# Histogram for PassengerId

# %%
dframe.PassengerId.hist()

# %% [markdown]
# ***Summary for PassengerId***
#
# <li> Is a continuous variable
# <li> There are no missing values for PassengerId
# <li> Minimum value for PassengerId is 1
# <li> Maximum value for PassengerId is 891
# <li> Mean for PassengerId is 446
# <li> Standard Deviation is 257.3538420152301
# <li> Each PassengerId from 1 to 891 was assigned to one person, or better to say that each passenger was assigned a unique ID

# %% [markdown]
# ***Survived EDA***

# %% [markdown]
# Is Survived continuous or categorical?

# %%
dframe.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %% [markdown]
# Appears that Survived is categorized as a boolean: 0 is "not survived" and 1 is "survived"

# %% [markdown]
# Are there any missing values for Survived?

# %%
dframe[dframe.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There are no missing values for Survived.

# %%
dframe.Survived.value_counts().plot(kind='bar')

# %% [markdown]
# #### ***Summary for Survived***
#
# <li> Survived is a categorial variable, where 0 is "did not survive" and 1 is "survived"
# <li> 549 passengers did not survive
# <li> 342 passengers did survive
# <li> There are no missing values for Survived

# %% [markdown]
# ***Pclass EDA***
#
# Is Pclass continuous or categorical?

# %%
dframe.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %% [markdown]
# Pclass is categorical - Describes First Class (1), Second/Middle Class (2), and Third/Low Class (3)

# %% [markdown]
# Are there any missing values for Pclass?

# %%
dframe[dframe.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There are no missing values for Pclass.

# %%
dframe.Pclass.value_counts().plot(kind='bar')

# %% [markdown]
# ***Summary for Pclass***
#
# <li> Pclass is categorical:  1 is First Class, 2 is Middle/Second Class, 3 is Low/Third Class
# <li> There are no missing values for Pclass
# <li> 216 First Class Passengers, 184 Second Class Passengers, and 491 Third Class Passengers
# <li> Appears that the highest category population is Third Class, then first, and finally second

# %% [markdown]
# *** Sex EDA***
#
# Is Sex categorical or continuous?

# %%
dframe.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %% [markdown]
# Sex is categorical:  male and female categories
#
# Are there any missing values?

# %%
dframe[dframe.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There are no missing values.

# %%
dframe.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# ***Summary for Sex***
#
# <li> Sex is categorical:  Male or Female
# <li> There are no missing values for Sex
# <li> 577 male passengers and 314 female passengers

# %% [markdown]
# *** EDA for SibSp***
#
# Is it categorical or continuous?

# %%
dframe.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# dtype: int64

# %% [markdown]
# SibSp is continuous

# %% [markdown]
# Missing values?

# %%
dframe[dframe.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There are no missing values for SibSp.

# %% [markdown]
# Minimum value

# %%
dframe.SibSp.min()
# Out:
# 0

# %% [markdown]
# Maximum value

# %%
dframe.SibSp.max()
# Out:
# 8

# %% [markdown]
# Mean value

# %%
dframe.SibSp.mean()
# Out:
# 0.5230078563411896

# %% [markdown]
# Standard deviation

# %%
dframe.SibSp.std()
# Out:
# 1.1027434322934275

# %%
dframe.SibSp.hist(bins=9)

# %% [markdown]
# *** Summary for SibSp ***
#
# <li> SibSp (number of siblings and spouse on board) is continuous
# <li> There are no missing values
# <li> Minimum value is 0 Siblings/spouse on board
# <li> Maximum value is 8 Siblings/spouse on board
# <li> Mean value is about 0.52
# <li> Standard Deviation is about 1.103
# <li> Appears that most of the passengers did not have a sibling or spouse on board

# %% [markdown]
# *** EDA for Parch ***
#
# Is Parch continuous or categorical?

# %%
dframe.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# dtype: int64

# %% [markdown]
# Parch is continuous

# %% [markdown]
# Are there any missing values?

# %%
dframe[dframe.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There are no missing values for Parch.

# %% [markdown]
# Minimum value for Parch

# %%
dframe.Parch.min()
# Out:
# 0

# %% [markdown]
# Maximum value for Parch

# %%
dframe.Parch.max()
# Out:
# 6

# %% [markdown]
# Mean value for Parch

# %%
dframe.Parch.mean()
# Out:
# 0.38159371492704824

# %% [markdown]
# Standard Deviation for Parch

# %%
dframe.Parch.std()
# Out:
# 0.8060572211299559

# %%
dframe.Parch.hist(bins=7)

# %% [markdown]
# ***Summary for Parch***
#
# <li> Parch is continuous (Parent/Child on board)
# <li> There are no missing values
# <li> The minimum value is 0
# <li> The maximum value is 6
# <li> The mean value is 0.38
# <li> The standard deviation is 0.806
# <li> Appears that most of the passengers did not travel with a parent or child

# %% [markdown]
# *** Ticket EDA ***

# %% [markdown]
# Is it continuous or categorical?

# %%
dframe.Ticket.value_counts()
# Out:
# CA. 2343             7
# 347082               7
# 1601                 7
# 347088               6
# CA 2144              6
# 3101295              6
# 382652               5
# S.O.C. 14879         5
# PC 17757             4
# 4133                 4
# LINE                 4
# 349909               4
# 347077               4
# W./C. 6608           4
# 113760               4
# 2666                 4
# 113781               4
# 19950                4
# 17421                4
# 347742               3
# 239853               3
# 110152               3
# 24160                3
# 13502                3
# PC 17572             3
# C.A. 34651           3
# 248727               3
# 35273                3
# F.C.C. 13529         3
# PC 17755             3
#                     ..
# 330877               1
# 315094               1
# 236852               1
# 4137                 1
# 4136                 1
# 226593               1
# 4134                 1
# 374746               1
# 110813               1
# C.A. 6212            1
# 349219               1
# 34218                1
# 343120               1
# 315086               1
# SC/AH 3085           1
# STON/O 2. 3101273    1
# 345777               1
# STON/O 2. 3101274    1
# STON/O 2. 3101275    1
# 113794               1
# 2649                 1
# 374887               1
# 349213               1
# 349210               1
# 349242               1
# 349216               1
# 112052               1
# 315088               1
# 349215               1
# W./C. 14258          1
# dtype: int64

# %% [markdown]
# Ticket appears continuous since ticket numbers change, however tickets do not follow an incremental numerical pattern. Letters and words are weaved into ticket. This leads to possibly having to group by prefixes, which could make this categorical in nature (tickets bought with this group of people who are together, or bought at this port, etc). Will group by: Numeric, Pre-fixed, and "Line" tickets to satisfy a preliminary look at the data.  Should actually focus on what the prefixes are, group by specific prefix, and see how that relates to other variables.

# %% [markdown]
# Are there null values?

# %%
dframe[dframe.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There are no missing values.

# %% [markdown]
# Numeric only tickets

# %%
dframe[dframe.Ticket.str.match('[0-9]')].Ticket.count()
# Out:
# 661

# %% [markdown]
# Pre-fixed tickets

# %%
dframe[dframe.Ticket.str.match('[a-zA-Z].*[0-9]')].Ticket.count()
# Out:
# 226

# %% [markdown]
# "LINE" tickets

# %%
dframe[dframe.Ticket.str.match('^[^0-9]*$')].Ticket.count()
# Out:
# 4

# %%
dframe.Ticket = dframe.Ticket.replace({'^[^0-9]*$' : 'LINE'}, regex=True)

# %%
dframe.Ticket = dframe.Ticket.replace({'[a-zA-Z].*[0-9]': 'PREFIX'} , regex=True)

# %%
dframe.Ticket = dframe.Ticket.replace({'^[0-9]*$': 'NUMERIC'} , regex=True)

# %%
dframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# 5                                     Moran, Mr. James    male  NaN      0
# 6                              McCarthy, Mr. Timothy J    male   54      0
# 7                       Palsson, Master. Gosta Leonard    male    2      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
# 10                     Sandstrom, Miss. Marguerite Rut  female    4      1
# 11                            Bonnell, Miss. Elizabeth  female   58      0
# 12                      Saundercock, Mr. William Henry    male   20      0
# 13                         Andersson, Mr. Anders Johan    male   39      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female   14      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female   55      0
# 16                                Rice, Master. Eugene    male    2      4
# 17                        Williams, Mr. Charles Eugene    male  NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female   31      1
# 19                             Masselmani, Mrs. Fatima  female  NaN      0
# 20                                Fynney, Mr. Joseph J    male   35      0
# 21                               Beesley, Mr. Lawrence    male   34      0
# 22                         McGowan, Miss. Anna "Annie"  female   15      0
# 23                        Sloper, Mr. William Thompson    male   28      0
# 24                       Palsson, Miss. Torborg Danira  female    8      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female   38      1
# 26                             Emir, Mr. Farred Chehab    male  NaN      0
# 27                      Fortune, Mr. Charles Alexander    male   19      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
# 29                                 Todoroff, Mr. Lalio    male  NaN      0
# ..                                                 ...     ...  ...    ...
# 861                        Giles, Mr. Frederick Edward    male   21      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female   48      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  NaN      8
# 864                             Gill, Mr. John William    male   24      0
# 865                           Bystrom, Mrs. (Karolina)  female   42      0
# 866                       Duran y More, Miss. Asuncion  female   27      1
# 867               Roebling, Mr. Washington Augustus II    male   31      0
# 868                        van Melkebeke, Mr. Philemon    male  NaN      0
# 869                    Johnson, Master. Harold Theodor    male    4      1
# 870                                  Balkic, Mr. Cerin    male   26      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female   47      1
# 872                           Carlsson, Mr. Frans Olof    male   33      0
# 873                        Vander Cruyssen, Mr. Victor    male   47      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female   28      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female   15      0
# 876                      Gustafsson, Mr. Alfred Ossian    male   20      0
# 877                               Petroff, Mr. Nedelio    male   19      0
# 878                                 Laleff, Mr. Kristo    male  NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female   25      0
# 881                                 Markun, Mr. Johann    male   33      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female   22      0
# 883                      Banfield, Mr. Frederick James    male   28      0
# 884                             Sutehall, Mr. Henry Jr    male   25      0
# 885               Rice, Mrs. William (Margaret Norton)  female   39      0
# 886                              Montvila, Rev. Juozas    male   27      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
# 889                              Behr, Mr. Karl Howell    male   26      0
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch   Ticket      Fare        Cabin Embarked
# 0        0   PREFIX    7.2500          NaN        S
# 1        0   PREFIX   71.2833          C85        C
# 2        0   PREFIX    7.9250          NaN        S
# 3        0  NUMERIC   53.1000         C123        S
# 4        0  NUMERIC    8.0500          NaN        S
# 5        0  NUMERIC    8.4583          NaN        Q
# 6        0  NUMERIC   51.8625          E46        S
# 7        1  NUMERIC   21.0750          NaN        S
# 8        2  NUMERIC   11.1333          NaN        S
# 9        0  NUMERIC   30.0708          NaN        C
# 10       1   PREFIX   16.7000           G6        S
# 11       0  NUMERIC   26.5500         C103        S
# 12       0   PREFIX    8.0500          NaN        S
# 13       5  NUMERIC   31.2750          NaN        S
# 14       0  NUMERIC    7.8542          NaN        S
# 15       0  NUMERIC   16.0000          NaN        S
# 16       1  NUMERIC   29.1250          NaN        Q
# 17       0  NUMERIC   13.0000          NaN        S
# 18       0  NUMERIC   18.0000          NaN        S
# 19       0  NUMERIC    7.2250          NaN        C
# 20       0  NUMERIC   26.0000          NaN        S
# 21       0  NUMERIC   13.0000          D56        S
# 22       0  NUMERIC    8.0292          NaN        Q
# 23       0  NUMERIC   35.5000           A6        S
# 24       1  NUMERIC   21.0750          NaN        S
# 25       5  NUMERIC   31.3875          NaN        S
# 26       0  NUMERIC    7.2250          NaN        C
# 27       2  NUMERIC  263.0000  C23 C25 C27        S
# 28       0  NUMERIC    7.8792          NaN        Q
# 29       0  NUMERIC    7.8958          NaN        S
# ..     ...      ...       ...          ...      ...
# 861      0  NUMERIC   11.5000          NaN        S
# 862      0  NUMERIC   25.9292          D17        S
# 863      2   PREFIX   69.5500          NaN        S
# 864      0  NUMERIC   13.0000          NaN        S
# 865      0  NUMERIC   13.0000          NaN        S
# 866      0   PREFIX   13.8583          NaN        C
# 867      0   PREFIX   50.4958          A24        S
# 868      0  NUMERIC    9.5000          NaN        S
# 869      1  NUMERIC   11.1333          NaN        S
# 870      0  NUMERIC    7.8958          NaN        S
# 871      1  NUMERIC   52.5542          D35        S
# 872      0  NUMERIC    5.0000  B51 B53 B55        S
# 873      0  NUMERIC    9.0000          NaN        S
# 874      0   PREFIX   24.0000          NaN        C
# 875      0  NUMERIC    7.2250          NaN        C
# 876      0  NUMERIC    9.8458          NaN        S
# 877      0  NUMERIC    7.8958          NaN        S
# 878      0  NUMERIC    7.8958          NaN        S
# 879      1  NUMERIC   83.1583          C50        C
# 880      1  NUMERIC   26.0000          NaN        S
# 881      0  NUMERIC    7.8958          NaN        S
# 882      0  NUMERIC   10.5167          NaN        S
# 883      0   PREFIX   10.5000          NaN        S
# 884      0   PREFIX    7.0500          NaN        S
# 885      5  NUMERIC   29.1250          NaN        Q
# 886      0  NUMERIC   13.0000          NaN        S
# 887      0  NUMERIC   30.0000          B42        S
# 888      2   PREFIX   23.4500          NaN        S
# 889      0  NUMERIC   30.0000         C148        C
# 890      0  NUMERIC    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %%
dframe.Ticket.value_counts()
# Out:
# NUMERIC    661
# PREFIX     226
# LINE         4
# dtype: int64

# %%
dframe.Ticket.value_counts().plot(kind='bar')

# %%
dframe[dframe.Ticket=='LINE']
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 179          180         0       3              Leonard, Mr. Lionel  male
# 271          272         1       3     Tornquist, Mr. William Henry  male
# 302          303         0       3  Johnson, Mr. William Cahoone Jr  male
# 597          598         0       3              Johnson, Mr. Alfred  male
#
#      Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 179   36      0      0   LINE     0   NaN        S
# 271   25      0      0   LINE     0   NaN        S
# 302   19      0      0   LINE     0   NaN        S
# 597   49      0      0   LINE     0   NaN        S

# %% [markdown]
# ***Note of Interest concerning Mr. William Henry Tornquist***
# After looking up his information on the encyclopedia titanica, it appears that he actually has a ticket number assigned to him - 370160.  More research is needed to correct this column if this is the first discrepancy to appear.

# %%
dframe[dframe.Ticket=='PREFIX']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 10            11         1       3
# 12            13         0       3
# 30            31         0       1
# 31            32         1       1
# 33            34         0       2
# 34            35         0       1
# 37            38         0       3
# 43            44         1       2
# 45            46         0       3
# 51            52         0       3
# 52            53         1       1
# 56            57         1       2
# 58            59         1       2
# 59            60         0       3
# 64            65         0       1
# 66            67         1       2
# 67            68         0       3
# 70            71         0       2
# 71            72         0       3
# 72            73         0       2
# 84            85         1       2
# 86            87         0       3
# 87            88         0       3
# 92            93         0       1
# 93            94         0       3
# 96            97         0       1
# 97            98         1       1
# ..           ...       ...     ...
# 744          745         1       3
# 745          746         0       1
# 746          747         0       3
# 761          762         0       3
# 772          773         0       2
# 783          784         0       3
# 784          785         0       3
# 788          789         1       3
# 789          790         0       1
# 792          793         0       3
# 793          794         0       1
# 801          802         1       2
# 811          812         0       3
# 816          817         0       3
# 817          818         0       2
# 818          819         0       3
# 827          828         1       2
# 835          836         1       1
# 840          841         0       3
# 841          842         0       2
# 845          846         0       3
# 846          847         0       3
# 853          854         1       1
# 863          864         0       3
# 866          867         1       2
# 867          868         0       1
# 874          875         1       2
# 883          884         0       2
# 884          885         0       3
# 888          889         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 10                     Sandstrom, Miss. Marguerite Rut  female    4      1
# 12                      Saundercock, Mr. William Henry    male   20      0
# 30                            Uruchurtu, Don. Manuel E    male   40      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1
# 33                               Wheadon, Mr. Edward H    male   66      0
# 34                             Meyer, Mr. Edgar Joseph    male   28      1
# 37                            Cann, Mr. Ernest Charles    male   21      0
# 43            Laroche, Miss. Simonne Marie Anne Andree  female    3      1
# 45                            Rogers, Mr. William John    male  NaN      0
# 51                        Nosworthy, Mr. Richard Cater    male   21      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female   49      1
# 56                                   Rugg, Miss. Emily  female   21      0
# 58                        West, Miss. Constance Mirium  female    5      1
# 59                  Goodwin, Master. William Frederick    male   11      5
# 64                               Stewart, Mr. Albert A    male  NaN      0
# 66                        Nye, Mrs. (Elizabeth Ramell)  female   29      0
# 67                            Crease, Mr. Ernest James    male   19      0
# 70                          Jenkin, Mr. Stephen Curnow    male   32      0
# 71                          Goodwin, Miss. Lillian Amy  female   16      5
# 72                                Hood, Mr. Ambrose Jr    male   21      0
# 84                                 Ilett, Miss. Bertha  female   17      0
# 86                              Ford, Mr. William Neal    male   16      1
# 87                       Slocovski, Mr. Selman Francis    male  NaN      0
# 92                         Chaffee, Mr. Herbert Fuller    male   46      1
# 93                             Dean, Mr. Bertram Frank    male   26      1
# 96                           Goldschmidt, Mr. George B    male   71      0
# 97                     Greenfield, Mr. William Bertram    male   23      0
# ..                                                 ...     ...  ...    ...
# 744                                 Stranden, Mr. Juho    male   31      0
# 745                       Crosby, Capt. Edward Gifford    male   70      1
# 746                        Abbott, Mr. Rossmore Edward    male   16      1
# 761                     Nirva, Mr. Iisakki Antino Aijo    male   41      0
# 772                                  Mack, Mrs. (Mary)  female   57      0
# 783                             Johnston, Mr. Andrew G    male  NaN      1
# 784                                   Ali, Mr. William    male   25      0
# 788                         Dean, Master. Bertram Vere    male    1      1
# 789                           Guggenheim, Mr. Benjamin    male   46      0
# 792                            Sage, Miss. Stella Anna  female  NaN      8
# 793                           Hoyt, Mr. William Fisher    male  NaN      0
# 801        Collyer, Mrs. Harvey (Charlotte Annie Tate)  female   31      1
# 811                                  Lester, Mr. James    male   39      0
# 816                       Heininen, Miss. Wendla Maria  female   23      0
# 817                                 Mallet, Mr. Albert    male   31      1
# 818                   Holm, Mr. John Fredrik Alexander    male   43      0
# 827                              Mallet, Master. Andre    male    1      0
# 835                        Compton, Miss. Sara Rebecca  female   39      1
# 840                        Alhomaki, Mr. Ilmari Rudolf    male   20      0
# 841                           Mudd, Mr. Thomas Charles    male   16      0
# 845                                Abbing, Mr. Anthony    male   42      0
# 846                           Sage, Mr. Douglas Bullen    male  NaN      8
# 853                          Lines, Miss. Mary Conover  female   16      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  NaN      8
# 866                       Duran y More, Miss. Asuncion  female   27      1
# 867               Roebling, Mr. Washington Augustus II    male   31      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female   28      1
# 883                      Banfield, Mr. Frederick James    male   28      0
# 884                             Sutehall, Mr. Henry Jr    male   25      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
#
#      Parch  Ticket      Fare    Cabin Embarked
# 0        0  PREFIX    7.2500      NaN        S
# 1        0  PREFIX   71.2833      C85        C
# 2        0  PREFIX    7.9250      NaN        S
# 10       1  PREFIX   16.7000       G6        S
# 12       0  PREFIX    8.0500      NaN        S
# 30       0  PREFIX   27.7208      NaN        C
# 31       0  PREFIX  146.5208      B78        C
# 33       0  PREFIX   10.5000      NaN        S
# 34       0  PREFIX   82.1708      NaN        C
# 37       0  PREFIX    8.0500      NaN        S
# 43       2  PREFIX   41.5792      NaN        C
# 45       0  PREFIX    8.0500      NaN        S
# 51       0  PREFIX    7.8000      NaN        S
# 52       0  PREFIX   76.7292      D33        C
# 56       0  PREFIX   10.5000      NaN        S
# 58       2  PREFIX   27.7500      NaN        S
# 59       2  PREFIX   46.9000      NaN        S
# 64       0  PREFIX   27.7208      NaN        C
# 66       0  PREFIX   10.5000      F33        S
# 67       0  PREFIX    8.1583      NaN        S
# 70       0  PREFIX   10.5000      NaN        S
# 71       2  PREFIX   46.9000      NaN        S
# 72       0  PREFIX   73.5000      NaN        S
# 84       0  PREFIX   10.5000      NaN        S
# 86       3  PREFIX   34.3750      NaN        S
# 87       0  PREFIX    8.0500      NaN        S
# 92       0  PREFIX   61.1750      E31        S
# 93       2  PREFIX   20.5750      NaN        S
# 96       0  PREFIX   34.6542       A5        C
# 97       1  PREFIX   63.3583  D10 D12        C
# ..     ...     ...       ...      ...      ...
# 744      0  PREFIX    7.9250      NaN        S
# 745      1  PREFIX   71.0000      B22        S
# 746      1  PREFIX   20.2500      NaN        S
# 761      0  PREFIX    7.1250      NaN        S
# 772      0  PREFIX   10.5000      E77        S
# 783      2  PREFIX   23.4500      NaN        S
# 784      0  PREFIX    7.0500      NaN        S
# 788      2  PREFIX   20.5750      NaN        S
# 789      0  PREFIX   79.2000  B82 B84        C
# 792      2  PREFIX   69.5500      NaN        S
# 793      0  PREFIX   30.6958      NaN        C
# 801      1  PREFIX   26.2500      NaN        S
# 811      0  PREFIX   24.1500      NaN        S
# 816      0  PREFIX    7.9250      NaN        S
# 817      1  PREFIX   37.0042      NaN        C
# 818      0  PREFIX    6.4500      NaN        S
# 827      2  PREFIX   37.0042      NaN        C
# 835      1  PREFIX   83.1583      E49        C
# 840      0  PREFIX    7.9250      NaN        S
# 841      0  PREFIX   10.5000      NaN        S
# 845      0  PREFIX    7.5500      NaN        S
# 846      2  PREFIX   69.5500      NaN        S
# 853      1  PREFIX   39.4000      D28        S
# 863      2  PREFIX   69.5500      NaN        S
# 866      0  PREFIX   13.8583      NaN        C
# 867      0  PREFIX   50.4958      A24        S
# 874      0  PREFIX   24.0000      NaN        C
# 883      0  PREFIX   10.5000      NaN        S
# 884      0  PREFIX    7.0500      NaN        S
# 888      2  PREFIX   23.4500      NaN        S
#
# [226 rows x 12 columns]

# %% [markdown]
# *** Summary for Ticket ***
#
# <li> Ticket initially appears to be continuous, but further analysis appears to point to this being categorical in nature:  there are numeric ticket numbers, ticket numbers with prefixes, and four tickets with LINE assigned for ticket number.  Seems that passengers are assigned to a ticket "group" of one or more passengers.
# <li> One of the "LINE" entries from the original csv file should be changed to an actual ticket number for Mr. William Henry Tornquist.  Might be other cases of incorrect ticket number values.
# <li> It appears that most passengers had a numerical style ticket number.

# %% [markdown]
# *** EDA for Fare ***
#
# Is it categorical or continuous?

# %%
dframe.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 7.2292     15
# 26.5500    15
# 0.0000     15
# 7.2500     13
# 7.8542     13
# 8.6625     13
# 7.2250     12
# 16.1000     9
# 9.5000      9
# 15.5000     8
# 24.1500     8
# 14.4542     7
# 14.5000     7
# 56.4958     7
# 69.5500     7
# 52.0000     7
# 31.2750     7
# 7.0500      7
# 27.9000     6
# 21.0000     6
# 26.2500     6
# 30.0000     6
#            ..
# 5.0000      1
# 71.2833     1
# 9.4833      1
# 59.4000     1
# 25.5875     1
# 15.0458     1
# 7.7875      1
# 8.4042      1
# 12.0000     1
# 12.2750     1
# 42.4000     1
# 8.1375      1
# 14.0000     1
# 21.6792     1
# 12.5250     1
# 15.0000     1
# 28.7125     1
# 61.1750     1
# 6.2375      1
# 15.1000     1
# 39.4000     1
# 81.8583     1
# 61.9792     1
# 7.8000      1
# 22.0250     1
# 47.1000     1
# 13.4167     1
# 14.1083     1
# 15.5500     1
# 13.7917     1
# dtype: int64

# %% [markdown]
# Fare is continous

# %%
dframe[dframe.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There are no missing values for Fare.

# %% [markdown]
# Minimum value for Fare

# %%
dframe.Fare.min()
# Out:
# 0.0

# %% [markdown]
# Maximum value for Fare

# %%
dframe.Fare.max()
# Out:
# 512.3292

# %% [markdown]
# Mean for Fare

# %%
dframe.Fare.mean()
# Out:
# 32.2042079685746

# %% [markdown]
# Standard Deviation for Fare

# %%
dframe.Fare.std()
# Out:
# 49.693428597180905

# %%
dframe.Fare.hist(bins=5)

# %% [markdown]
# *** Summary for Fare ***
#
# <li> Fare is a continuous variable covering price of ticket
# <li> There are no missing values for Fare
# <li> Minimum value of 0.0
# <li> Maximum value of 512.32
# <li> Mean value of Fare is 32.20
# <li> Standard deviation is about 49.69
# <li> Appears that the majority of passengers paid for a ticket that is less than 100

# %% [markdown]
# *** EDA for Age ***
#
# Is Age categorical or continuous?

# %%
dframe.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
# 19.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 35.00    18
# 27.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 33.00    15
# 20.00    15
# 34.00    15
# 23.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 4.00     10
# 50.00    10
# 2.00     10
# 47.00     9
#          ..
# 40.50     2
# 10.00     2
# 13.00     2
# 45.50     2
# 64.00     2
# 71.00     2
# 70.00     2
# 30.50     2
# 0.83      2
# 63.00     2
# 59.00     2
# 57.00     2
# 55.00     2
# 0.75      2
# 0.42      1
# 53.00     1
# 70.50     1
# 14.50     1
# 0.92      1
# 74.00     1
# 36.50     1
# 80.00     1
# 12.00     1
# 55.50     1
# 34.50     1
# 24.50     1
# 66.00     1
# 23.50     1
# 0.67      1
# 20.50     1
# dtype: int64

# %% [markdown]
# Age is continuous

# %%
dframe[dframe.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# 121          122         0       3
# 126          127         0       3
# 128          129         1       3
# 140          141         0       3
# 154          155         0       3
# ..           ...       ...     ...
# 718          719         0       3
# 727          728         1       3
# 732          733         0       2
# 738          739         0       3
# 739          740         0       3
# 740          741         1       1
# 760          761         0       3
# 766          767         0       1
# 768          769         0       3
# 773          774         0       3
# 776          777         0       3
# 778          779         0       3
# 783          784         0       3
# 790          791         0       3
# 792          793         0       3
# 793          794         0       1
# 815          816         0       1
# 825          826         0       3
# 826          827         0       3
# 828          829         1       3
# 832          833         0       3
# 837          838         0       3
# 839          840         1       1
# 846          847         0       3
# 849          850         1       1
# 859          860         0       3
# 863          864         0       3
# 868          869         0       3
# 878          879         0       3
# 888          889         0       3
#
#                                                Name     Sex  Age  SibSp  \
# 5                                  Moran, Mr. James    male  NaN      0
# 17                     Williams, Mr. Charles Eugene    male  NaN      0
# 19                          Masselmani, Mrs. Fatima  female  NaN      0
# 26                          Emir, Mr. Farred Chehab    male  NaN      0
# 28                    O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
# 29                              Todoroff, Mr. Lalio    male  NaN      0
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1
# 32                         Glynn, Miss. Mary Agatha  female  NaN      0
# 36                                 Mamee, Mr. Hanna    male  NaN      0
# 42                              Kraeff, Mr. Theodor    male  NaN      0
# 45                         Rogers, Mr. William John    male  NaN      0
# 46                                Lennon, Mr. Denis    male  NaN      1
# 47                        O'Driscoll, Miss. Bridget  female  NaN      0
# 48                              Samaan, Mr. Youssef    male  NaN      2
# 55                                Woolner, Mr. Hugh    male  NaN      0
# 64                            Stewart, Mr. Albert A    male  NaN      0
# 65                         Moubarek, Master. Gerios    male  NaN      1
# 76                                Staneff, Mr. Ivan    male  NaN      0
# 77                         Moutal, Mr. Rahamin Haim    male  NaN      0
# 82                   McDermott, Miss. Brigdet Delia  female  NaN      0
# 87                    Slocovski, Mr. Selman Francis    male  NaN      0
# 95                      Shorney, Mr. Charles Joseph    male  NaN      0
# 101                Petroff, Mr. Pastcho ("Pentcho")    male  NaN      0
# 107                          Moss, Mr. Albert Johan    male  NaN      0
# 109                             Moran, Miss. Bertha  female  NaN      1
# 121                      Moore, Mr. Leonard Charles    male  NaN      0
# 126                             McMahon, Mr. Martin    male  NaN      0
# 128                               Peter, Miss. Anna  female  NaN      1
# 140                   Boulos, Mrs. Joseph (Sultana)  female  NaN      0
# 154                           Olsen, Mr. Ole Martin    male  NaN      0
# ..                                              ...     ...  ...    ...
# 718                             McEvoy, Mr. Michael    male  NaN      0
# 727                        Mannion, Miss. Margareth  female  NaN      0
# 732                            Knight, Mr. Robert J    male  NaN      0
# 738                              Ivanoff, Mr. Kanio    male  NaN      0
# 739                              Nankoff, Mr. Minko    male  NaN      0
# 740                     Hawksford, Mr. Walter James    male  NaN      0
# 760                              Garfirth, Mr. John    male  NaN      0
# 766                       Brewe, Dr. Arthur Jackson    male  NaN      0
# 768                             Moran, Mr. Daniel J    male  NaN      1
# 773                                 Elias, Mr. Dibo    male  NaN      0
# 776                                Tobin, Mr. Roger    male  NaN      0
# 778                         Kilgannon, Mr. Thomas J    male  NaN      0
# 783                          Johnston, Mr. Andrew G    male  NaN      1
# 790                        Keane, Mr. Andrew "Andy"    male  NaN      0
# 792                         Sage, Miss. Stella Anna  female  NaN      8
# 793                        Hoyt, Mr. William Fisher    male  NaN      0
# 815                                Fry, Mr. Richard    male  NaN      0
# 825                                 Flynn, Mr. John    male  NaN      0
# 826                                    Lam, Mr. Len    male  NaN      0
# 828                    McCormack, Mr. Thomas Joseph    male  NaN      0
# 832                                  Saad, Mr. Amin    male  NaN      0
# 837                             Sirota, Mr. Maurice    male  NaN      0
# 839                            Marechal, Mr. Pierre    male  NaN      0
# 846                        Sage, Mr. Douglas Bullen    male  NaN      8
# 849    Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  NaN      1
# 859                                Razi, Mr. Raihed    male  NaN      0
# 863               Sage, Miss. Dorothy Edith "Dolly"  female  NaN      8
# 868                     van Melkebeke, Mr. Philemon    male  NaN      0
# 878                              Laleff, Mr. Kristo    male  NaN      0
# 888        Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
#
#      Parch   Ticket      Fare  Cabin Embarked
# 5        0  NUMERIC    8.4583    NaN        Q
# 17       0  NUMERIC   13.0000    NaN        S
# 19       0  NUMERIC    7.2250    NaN        C
# 26       0  NUMERIC    7.2250    NaN        C
# 28       0  NUMERIC    7.8792    NaN        Q
# 29       0  NUMERIC    7.8958    NaN        S
# 31       0   PREFIX  146.5208    B78        C
# 32       0  NUMERIC    7.7500    NaN        Q
# 36       0  NUMERIC    7.2292    NaN        C
# 42       0  NUMERIC    7.8958    NaN        C
# 45       0   PREFIX    8.0500    NaN        S
# 46       0  NUMERIC   15.5000    NaN        Q
# 47       0  NUMERIC    7.7500    NaN        Q
# 48       0  NUMERIC   21.6792    NaN        C
# 55       0  NUMERIC   35.5000    C52        S
# 64       0   PREFIX   27.7208    NaN        C
# 65       1  NUMERIC   15.2458    NaN        C
# 76       0  NUMERIC    7.8958    NaN        S
# 77       0  NUMERIC    8.0500    NaN        S
# 82       0  NUMERIC    7.7875    NaN        Q
# 87       0   PREFIX    8.0500    NaN        S
# 95       0  NUMERIC    8.0500    NaN        S
# 101      0  NUMERIC    7.8958    NaN        S
# 107      0  NUMERIC    7.7750    NaN        S
# 109      0  NUMERIC   24.1500    NaN        Q
# 121      0   PREFIX    8.0500    NaN        S
# 126      0  NUMERIC    7.7500    NaN        Q
# 128      1  NUMERIC   22.3583  F E69        C
# 140      2  NUMERIC   15.2458    NaN        C
# 154      0   PREFIX    7.3125    NaN        S
# ..     ...      ...       ...    ...      ...
# 718      0  NUMERIC   15.5000    NaN        Q
# 727      0  NUMERIC    7.7375    NaN        Q
# 732      0  NUMERIC    0.0000    NaN        S
# 738      0  NUMERIC    7.8958    NaN        S
# 739      0  NUMERIC    7.8958    NaN        S
# 740      0  NUMERIC   30.0000    D45        S
# 760      0  NUMERIC   14.5000    NaN        S
# 766      0  NUMERIC   39.6000    NaN        C
# 768      0  NUMERIC   24.1500    NaN        Q
# 773      0  NUMERIC    7.2250    NaN        C
# 776      0  NUMERIC    7.7500    F38        Q
# 778      0  NUMERIC    7.7375    NaN        Q
# 783      2   PREFIX   23.4500    NaN        S
# 790      0  NUMERIC    7.7500    NaN        Q
# 792      2   PREFIX   69.5500    NaN        S
# 793      0   PREFIX   30.6958    NaN        C
# 815      0  NUMERIC    0.0000   B102        S
# 825      0  NUMERIC    6.9500    NaN        Q
# 826      0  NUMERIC   56.4958    NaN        S
# 828      0  NUMERIC    7.7500    NaN        Q
# 832      0  NUMERIC    7.2292    NaN        C
# 837      0  NUMERIC    8.0500    NaN        S
# 839      0  NUMERIC   29.7000    C47        C
# 846      2   PREFIX   69.5500    NaN        S
# 849      0  NUMERIC   89.1042    C92        C
# 859      0  NUMERIC    7.2292    NaN        C
# 863      2   PREFIX   69.5500    NaN        S
# 868      0  NUMERIC    9.5000    NaN        S
# 878      0  NUMERIC    7.8958    NaN        S
# 888      2   PREFIX   23.4500    NaN        S
#
# [177 rows x 12 columns]

# %% [markdown]
# There are a 177 missing age values

# %%
dframe.Age.min()
# Out:
# 0.42

# %%
dframe.Age.max()
# Out:
# 80.0

# %%
dframe.Age.mean()
# Out:
# 29.69911764705882

# %%
dframe.Age.std()
# Out:
# 14.526497332334044

# %%
dframe.Age.hist(bins=10)

# %% [markdown]
# *** Summary for Age ***
#
# <li> Age is a continuous variable
# <li> There are 177 missing age values
# <li> The minimum age is 0.42, assuming this means about 5 months old
# <li> The maximum age is 80 years
# <li> The mean age is 29.69 years
# <li> The Standard Deviation is about 14.52 years
# <li> It appears that highest populated age group would be around 20 to 30 years old.

# %% [markdown]
# *** EDA for Cabin ***
#
# Is it continuous or categorical?

# %%
dframe.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# B77                2
# C65                2
# D26                2
# E24                2
# E25                2
# B20                2
# C93                2
# D33                2
# E67                2
# D35                2
# D36                2
# C52                2
# F4                 2
# C125               2
# C124               2
#                   ..
# F G63              1
# A6                 1
# D45                1
# D6                 1
# D56                1
# C101               1
# C54                1
# D28                1
# D37                1
# B102               1
# D30                1
# E17                1
# E58                1
# F E69              1
# D10 D12            1
# E50                1
# A14                1
# C91                1
# A16                1
# B38                1
# B39                1
# C95                1
# B78                1
# B79                1
# C99                1
# B37                1
# A19                1
# E12                1
# A7                 1
# D15                1
# dtype: int64

# %% [markdown]
# Cabin appears to be categorical since the cabins are designated by deck (the letter), and room (the number). Also reviewed titanic deck map to understand the "pair/groups of cabins" instances.  It appears there are some cabin clusters on certain decks which in some instances groups (families, etc) would have been assigned to. Numbers appear to start from the front of the ship going towards the back (fore and aft).

# %% [markdown]
# Are there missing values?

# %%
dframe[dframe.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# 36            37         1       3
# 37            38         0       3
# 38            39         0       3
# ..           ...       ...     ...
# 852          853         0       3
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 4                             Allen, Mr. William Henry    male   35      0
# 5                                     Moran, Mr. James    male  NaN      0
# 7                       Palsson, Master. Gosta Leonard    male    2      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
# 12                      Saundercock, Mr. William Henry    male   20      0
# 13                         Andersson, Mr. Anders Johan    male   39      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female   14      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female   55      0
# 16                                Rice, Master. Eugene    male    2      4
# 17                        Williams, Mr. Charles Eugene    male  NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female   31      1
# 19                             Masselmani, Mrs. Fatima  female  NaN      0
# 20                                Fynney, Mr. Joseph J    male   35      0
# 22                         McGowan, Miss. Anna "Annie"  female   15      0
# 24                       Palsson, Miss. Torborg Danira  female    8      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female   38      1
# 26                             Emir, Mr. Farred Chehab    male  NaN      0
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
# 29                                 Todoroff, Mr. Lalio    male  NaN      0
# 30                            Uruchurtu, Don. Manuel E    male   40      0
# 32                            Glynn, Miss. Mary Agatha  female  NaN      0
# 33                               Wheadon, Mr. Edward H    male   66      0
# 34                             Meyer, Mr. Edgar Joseph    male   28      1
# 35                      Holverson, Mr. Alexander Oskar    male   42      1
# 36                                    Mamee, Mr. Hanna    male  NaN      0
# 37                            Cann, Mr. Ernest Charles    male   21      0
# 38                  Vander Planke, Miss. Augusta Maria  female   18      2
# ..                                                 ...     ...  ...    ...
# 852                            Boulos, Miss. Nourelain  female    9      1
# 854      Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female   44      1
# 855                         Aks, Mrs. Sam (Leah Rosen)  female   18      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female   45      1
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female   24      0
# 859                                   Razi, Mr. Raihed    male  NaN      0
# 860                            Hansen, Mr. Claus Peter    male   41      2
# 861                        Giles, Mr. Frederick Edward    male   21      1
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  NaN      8
# 864                             Gill, Mr. John William    male   24      0
# 865                           Bystrom, Mrs. (Karolina)  female   42      0
# 866                       Duran y More, Miss. Asuncion  female   27      1
# 868                        van Melkebeke, Mr. Philemon    male  NaN      0
# 869                    Johnson, Master. Harold Theodor    male    4      1
# 870                                  Balkic, Mr. Cerin    male   26      0
# 873                        Vander Cruyssen, Mr. Victor    male   47      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female   28      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female   15      0
# 876                      Gustafsson, Mr. Alfred Ossian    male   20      0
# 877                               Petroff, Mr. Nedelio    male   19      0
# 878                                 Laleff, Mr. Kristo    male  NaN      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female   25      0
# 881                                 Markun, Mr. Johann    male   33      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female   22      0
# 883                      Banfield, Mr. Frederick James    male   28      0
# 884                             Sutehall, Mr. Henry Jr    male   25      0
# 885               Rice, Mrs. William (Margaret Norton)  female   39      0
# 886                              Montvila, Rev. Juozas    male   27      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch   Ticket      Fare Cabin Embarked
# 0        0   PREFIX    7.2500   NaN        S
# 2        0   PREFIX    7.9250   NaN        S
# 4        0  NUMERIC    8.0500   NaN        S
# 5        0  NUMERIC    8.4583   NaN        Q
# 7        1  NUMERIC   21.0750   NaN        S
# 8        2  NUMERIC   11.1333   NaN        S
# 9        0  NUMERIC   30.0708   NaN        C
# 12       0   PREFIX    8.0500   NaN        S
# 13       5  NUMERIC   31.2750   NaN        S
# 14       0  NUMERIC    7.8542   NaN        S
# 15       0  NUMERIC   16.0000   NaN        S
# 16       1  NUMERIC   29.1250   NaN        Q
# 17       0  NUMERIC   13.0000   NaN        S
# 18       0  NUMERIC   18.0000   NaN        S
# 19       0  NUMERIC    7.2250   NaN        C
# 20       0  NUMERIC   26.0000   NaN        S
# 22       0  NUMERIC    8.0292   NaN        Q
# 24       1  NUMERIC   21.0750   NaN        S
# 25       5  NUMERIC   31.3875   NaN        S
# 26       0  NUMERIC    7.2250   NaN        C
# 28       0  NUMERIC    7.8792   NaN        Q
# 29       0  NUMERIC    7.8958   NaN        S
# 30       0   PREFIX   27.7208   NaN        C
# 32       0  NUMERIC    7.7500   NaN        Q
# 33       0   PREFIX   10.5000   NaN        S
# 34       0   PREFIX   82.1708   NaN        C
# 35       0  NUMERIC   52.0000   NaN        S
# 36       0  NUMERIC    7.2292   NaN        C
# 37       0   PREFIX    8.0500   NaN        S
# 38       0  NUMERIC   18.0000   NaN        S
# ..     ...      ...       ...   ...      ...
# 852      1  NUMERIC   15.2458   NaN        C
# 854      0  NUMERIC   26.0000   NaN        S
# 855      1  NUMERIC    9.3500   NaN        S
# 856      1  NUMERIC  164.8667   NaN        S
# 858      3  NUMERIC   19.2583   NaN        C
# 859      0  NUMERIC    7.2292   NaN        C
# 860      0  NUMERIC   14.1083   NaN        S
# 861      0  NUMERIC   11.5000   NaN        S
# 863      2   PREFIX   69.5500   NaN        S
# 864      0  NUMERIC   13.0000   NaN        S
# 865      0  NUMERIC   13.0000   NaN        S
# 866      0   PREFIX   13.8583   NaN        C
# 868      0  NUMERIC    9.5000   NaN        S
# 869      1  NUMERIC   11.1333   NaN        S
# 870      0  NUMERIC    7.8958   NaN        S
# 873      0  NUMERIC    9.0000   NaN        S
# 874      0   PREFIX   24.0000   NaN        C
# 875      0  NUMERIC    7.2250   NaN        C
# 876      0  NUMERIC    9.8458   NaN        S
# 877      0  NUMERIC    7.8958   NaN        S
# 878      0  NUMERIC    7.8958   NaN        S
# 880      1  NUMERIC   26.0000   NaN        S
# 881      0  NUMERIC    7.8958   NaN        S
# 882      0  NUMERIC   10.5167   NaN        S
# 883      0   PREFIX   10.5000   NaN        S
# 884      0   PREFIX    7.0500   NaN        S
# 885      5  NUMERIC   29.1250   NaN        Q
# 886      0  NUMERIC   13.0000   NaN        S
# 888      2   PREFIX   23.4500   NaN        S
# 890      0  NUMERIC    7.7500   NaN        Q
#
# [687 rows x 12 columns]

# %% [markdown]
# There are 687 missing values for cabin.

# %%
cabinFrame = dframe

# %% [markdown]
# Will try replacing existing values with just deck assignment for simplicity

# %%
cabinFrame.Cabin = dframe.Cabin.replace({'^A.*$': 'A', '^B.*$': 'B', '^C.*$': 'C', '^D.*$': 'D', '^E.*$': 'E', '^F.*$': 'F', '^G.*$': 'G'} , regex=True)

# %%
cabinFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# 5                                     Moran, Mr. James    male  NaN      0
# 6                              McCarthy, Mr. Timothy J    male   54      0
# 7                       Palsson, Master. Gosta Leonard    male    2      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
# 10                     Sandstrom, Miss. Marguerite Rut  female    4      1
# 11                            Bonnell, Miss. Elizabeth  female   58      0
# 12                      Saundercock, Mr. William Henry    male   20      0
# 13                         Andersson, Mr. Anders Johan    male   39      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female   14      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female   55      0
# 16                                Rice, Master. Eugene    male    2      4
# 17                        Williams, Mr. Charles Eugene    male  NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female   31      1
# 19                             Masselmani, Mrs. Fatima  female  NaN      0
# 20                                Fynney, Mr. Joseph J    male   35      0
# 21                               Beesley, Mr. Lawrence    male   34      0
# 22                         McGowan, Miss. Anna "Annie"  female   15      0
# 23                        Sloper, Mr. William Thompson    male   28      0
# 24                       Palsson, Miss. Torborg Danira  female    8      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female   38      1
# 26                             Emir, Mr. Farred Chehab    male  NaN      0
# 27                      Fortune, Mr. Charles Alexander    male   19      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
# 29                                 Todoroff, Mr. Lalio    male  NaN      0
# ..                                                 ...     ...  ...    ...
# 861                        Giles, Mr. Frederick Edward    male   21      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female   48      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  NaN      8
# 864                             Gill, Mr. John William    male   24      0
# 865                           Bystrom, Mrs. (Karolina)  female   42      0
# 866                       Duran y More, Miss. Asuncion  female   27      1
# 867               Roebling, Mr. Washington Augustus II    male   31      0
# 868                        van Melkebeke, Mr. Philemon    male  NaN      0
# 869                    Johnson, Master. Harold Theodor    male    4      1
# 870                                  Balkic, Mr. Cerin    male   26      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female   47      1
# 872                           Carlsson, Mr. Frans Olof    male   33      0
# 873                        Vander Cruyssen, Mr. Victor    male   47      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female   28      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female   15      0
# 876                      Gustafsson, Mr. Alfred Ossian    male   20      0
# 877                               Petroff, Mr. Nedelio    male   19      0
# 878                                 Laleff, Mr. Kristo    male  NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female   25      0
# 881                                 Markun, Mr. Johann    male   33      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female   22      0
# 883                      Banfield, Mr. Frederick James    male   28      0
# 884                             Sutehall, Mr. Henry Jr    male   25      0
# 885               Rice, Mrs. William (Margaret Norton)  female   39      0
# 886                              Montvila, Rev. Juozas    male   27      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
# 889                              Behr, Mr. Karl Howell    male   26      0
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch   Ticket      Fare Cabin Embarked
# 0        0   PREFIX    7.2500   NaN        S
# 1        0   PREFIX   71.2833     C        C
# 2        0   PREFIX    7.9250   NaN        S
# 3        0  NUMERIC   53.1000     C        S
# 4        0  NUMERIC    8.0500   NaN        S
# 5        0  NUMERIC    8.4583   NaN        Q
# 6        0  NUMERIC   51.8625     E        S
# 7        1  NUMERIC   21.0750   NaN        S
# 8        2  NUMERIC   11.1333   NaN        S
# 9        0  NUMERIC   30.0708   NaN        C
# 10       1   PREFIX   16.7000     G        S
# 11       0  NUMERIC   26.5500     C        S
# 12       0   PREFIX    8.0500   NaN        S
# 13       5  NUMERIC   31.2750   NaN        S
# 14       0  NUMERIC    7.8542   NaN        S
# 15       0  NUMERIC   16.0000   NaN        S
# 16       1  NUMERIC   29.1250   NaN        Q
# 17       0  NUMERIC   13.0000   NaN        S
# 18       0  NUMERIC   18.0000   NaN        S
# 19       0  NUMERIC    7.2250   NaN        C
# 20       0  NUMERIC   26.0000   NaN        S
# 21       0  NUMERIC   13.0000     D        S
# 22       0  NUMERIC    8.0292   NaN        Q
# 23       0  NUMERIC   35.5000     A        S
# 24       1  NUMERIC   21.0750   NaN        S
# 25       5  NUMERIC   31.3875   NaN        S
# 26       0  NUMERIC    7.2250   NaN        C
# 27       2  NUMERIC  263.0000     C        S
# 28       0  NUMERIC    7.8792   NaN        Q
# 29       0  NUMERIC    7.8958   NaN        S
# ..     ...      ...       ...   ...      ...
# 861      0  NUMERIC   11.5000   NaN        S
# 862      0  NUMERIC   25.9292     D        S
# 863      2   PREFIX   69.5500   NaN        S
# 864      0  NUMERIC   13.0000   NaN        S
# 865      0  NUMERIC   13.0000   NaN        S
# 866      0   PREFIX   13.8583   NaN        C
# 867      0   PREFIX   50.4958     A        S
# 868      0  NUMERIC    9.5000   NaN        S
# 869      1  NUMERIC   11.1333   NaN        S
# 870      0  NUMERIC    7.8958   NaN        S
# 871      1  NUMERIC   52.5542     D        S
# 872      0  NUMERIC    5.0000     B        S
# 873      0  NUMERIC    9.0000   NaN        S
# 874      0   PREFIX   24.0000   NaN        C
# 875      0  NUMERIC    7.2250   NaN        C
# 876      0  NUMERIC    9.8458   NaN        S
# 877      0  NUMERIC    7.8958   NaN        S
# 878      0  NUMERIC    7.8958   NaN        S
# 879      1  NUMERIC   83.1583     C        C
# 880      1  NUMERIC   26.0000   NaN        S
# 881      0  NUMERIC    7.8958   NaN        S
# 882      0  NUMERIC   10.5167   NaN        S
# 883      0   PREFIX   10.5000   NaN        S
# 884      0   PREFIX    7.0500   NaN        S
# 885      5  NUMERIC   29.1250   NaN        Q
# 886      0  NUMERIC   13.0000   NaN        S
# 887      0  NUMERIC   30.0000     B        S
# 888      2   PREFIX   23.4500   NaN        S
# 889      0  NUMERIC   30.0000     C        C
# 890      0  NUMERIC    7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
cabinFrame.Cabin.value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# T     1
# dtype: int64

# %%
cabinFrame[cabinFrame.Cabin=='T']
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex  Age  \
# 339          340         0       1  Blackwell, Mr. Stephen Weart  male   45
#
#      SibSp  Parch   Ticket  Fare Cabin Embarked
# 339      0      0  NUMERIC  35.5     T        S

# %% [markdown]
# Cabin T is on the "boat deck" of the Titanic.

# %%
cabinFrame.Cabin.value_counts().plot(kind='bar')

# %% [markdown]
# *** Summary of Cabin ***
#
# <li> Cabin appears to be categorical according to deck, more refined grouping could be derived from analyzing number.
# <li> There are 687 missing values for cabin.
# <li> From data available in the dataset, it appears that the highest population decks are C and B. However, this is not accounting for the large amount of missing cabin information for the other passengers.

# %% [markdown]
# *** Embarked EDA ***
#
# Is Embarked continuous or categorical?

# %%
dframe.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %% [markdown]
# Are there missing values?

# %%
dframe[dframe.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 61   female   38      0      0  NUMERIC    80     B      NaN
# 829  female   62      0      0  NUMERIC    80     B      NaN

# %% [markdown]
# Two passengers missing Embarked information.

# %%
dframe.Embarked.value_counts().plot(kind='bar')

# %% [markdown]
# Appears that the majority of passengers boarded at Southampton.

# %% [markdown]
# *** Summary for Embarked ***
# <li> Embarked is categorical: S = Southampton, C = Cherbourg, Q = Queenstown
# <li> There are only two missing instances in the dataset
# <li> Appears that the majority of passengers boarded at Southampton
